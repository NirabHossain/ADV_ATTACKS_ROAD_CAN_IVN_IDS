# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
# Load merged dataset
df=pd.read_csv("road/preprocessed/merged/attack_data_without_masquerade.csv")

X = df.drop(columns=['Flag'], errors='ignore')
y = df['Flag']

# Stratified split Train/Test (70/30)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.7, random_state=42, stratify=y
)

# Confirm sizes
print("Train samples:", len(X_train))
print("Test samples:", len(X_test))
results = []
# Out:
# Train samples: 1078308
# Test samples: 462133

# %%
"""----------DNN----------"""
#for bs in batch_sizes:
print(f"\nTraining with batch size: 32")
model = Sequential([   
Input(shape=(X_train.shape[1],)),  # Input layer (should be 10 features)
Dense(16, activation='relu'),#Dropout(0.3),
Dense(16, activation='relu'),#Dropout(0.3),
Dense(16, activation='relu'),#Dropout(0.3),
Dense(16, activation='relu'),#Dropout(0.3),
Dense(1, activation='sigmoid')  # Output layer: 1 neurons
])  # Rebuild model from scratch
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

history = model.fit(X_train, y_train, validation_split=0.1, epochs=50, batch_size=32, verbose=1)

    # ----- Predict -----
y_pred_prob = model.predict(X_test, batch_size=1024)
y_pred = (y_pred_prob > 0.5).astype(int)

# ----- Evaluation -----
# Convert multiclass to binary: 0 = normal, 1 = any attack
y_test_binary = (y_test != 0).astype(int)
y_pred_binary = (y_pred != 0).astype(int)

# Calculate F1 score and confusion matrix
f1 = f1_score(y_test_binary, y_pred_binary, zero_division=0)
cm = confusion_matrix(y_test_binary, y_pred_binary)
tn, fp, fn, tp = cm.ravel()
# Store in your results table
dnn=model
results.append(["DNN", tn, tp, f"{f1*100:.1f}%", fn, fp])
results_df = pd.DataFrame(results, columns=["Model", "Benign Samples", "Malicious Samples", "F1 score", "FN", "FP"])
display(results_df)
# Out:
# Training with batch size: 32
# Epoch 1/50
# 30328/30328 [==============================] - 73s 2ms/step - loss: 0.0645 - accuracy: 0.9799 - val_loss: 0.0427 - val_accuracy: 0.9853
# Epoch 2/50
# 30328/30328 [==============================] - 67s 2ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 0.0383 - val_accuracy: 0.9874
# Epoch 3/50
# 30328/30328 [==============================] - 77s 3ms/step - loss: 0.0402 - accuracy: 0.9870 - val_loss: 0.0388 - val_accuracy: 0.9879
# Epoch 4/50
# 30328/30328 [==============================] - 68s 2ms/step - loss: 0.0384 - accuracy: 0.9876 - val_loss: 0.0351 - val_accuracy: 0.9885
# Epoch 5/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 0.0368 - val_accuracy: 0.9883
# Epoch 6/50
# 30328/30328 [==============================] - 67s 2ms/step - loss: 0.0359 - accuracy: 0.9881 - val_loss: 0.0326 - val_accuracy: 0.9891
# Epoch 7/50
# 30328/30328 [==============================] - 67s 2ms/step - loss: 0.0358 - accuracy: 0.9882 - val_loss: 0.0328 - val_accuracy: 0.9893
# Epoch 8/50
# 30328/30328 [==============================] - 67s 2ms/step - loss: 0.0352 - accuracy: 0.9884 - val_loss: 0.0400 - val_accuracy: 0.9877
# Epoch 9/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0342 - accuracy: 0.9887 - val_loss: 0.0316 - val_accuracy: 0.9892
# Epoch 10/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0343 - accuracy: 0.9887 - val_loss: 0.0336 - val_accuracy: 0.9893
# Epoch 11/50
# 30328/30328 [==============================] - 65s 2ms/step - loss: 0.0339 - accuracy: 0.9887 - val_loss: 0.0329 - val_accuracy: 0.9892
# Epoch 12/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.0308 - val_accuracy: 0.9898
# Epoch 13/50
# 30328/30328 [==============================] - 65s 2ms/step - loss: 0.0335 - accuracy: 0.9890 - val_loss: 0.0481 - val_accuracy: 0.9835
# Epoch 14/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.0343 - val_accuracy: 0.9887
# Epoch 15/50
# 30328/30328 [==============================] - 65s 2ms/step - loss: 0.0334 - accuracy: 0.9889 - val_loss: 0.0302 - val_accuracy: 0.9895
# Epoch 16/50
# 30328/30328 [==============================] - 65s 2ms/step - loss: 0.0337 - accuracy: 0.9889 - val_loss: 0.0368 - val_accuracy: 0.9883
# Epoch 17/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.0302 - val_accuracy: 0.9900
# Epoch 18/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.0327 - val_accuracy: 0.9886
# Epoch 19/50
# 30328/30328 [==============================] - 65s 2ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.0303 - val_accuracy: 0.9903
# Epoch 20/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0330 - accuracy: 0.9892 - val_loss: 0.0297 - val_accuracy: 0.9899
# Epoch 21/50
# 30328/30328 [==============================] - 66s 2ms/step - loss: 0.0331 - accuracy: 0.9892 - val_loss: 0.0335 - val_accuracy: 0.9891
# Epoch 22/50
# 30328/30328 [==============================] - 90s 3ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.0308 - val_accuracy: 0.9899
# Epoch 23/50
# 30328/30328 [==============================] - 99s 3ms/step - loss: 0.0337 - accuracy: 0.9889 - val_loss: 0.0320 - val_accuracy: 0.9894
# Epoch 24/50
# 30328/30328 [==============================] - 94s 3ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.0363 - val_accuracy: 0.9882
# Epoch 25/50
# 30328/30328 [==============================] - 109s 4ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 0.0365 - val_accuracy: 0.9876
# Epoch 26/50
# 30328/30328 [==============================] - 109s 4ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.0313 - val_accuracy: 0.9893
# Epoch 27/50
# 30328/30328 [==============================] - 109s 4ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.0403 - val_accuracy: 0.9874
# Epoch 28/50
# 30328/30328 [==============================] - 112s 4ms/step - loss: 0.0330 - accuracy: 0.9892 - val_loss: 0.0296 - val_accuracy: 0.9902
# Epoch 29/50
# 30328/30328 [==============================] - 115s 4ms/step - loss: 0.0327 - accuracy: 0.9893 - val_loss: 0.0302 - val_accuracy: 0.9902
# Epoch 30/50
# 30328/30328 [==============================] - 123s 4ms/step - loss: 0.0326 - accuracy: 0.9893 - val_loss: 0.0310 - val_accuracy: 0.9889
# Epoch 31/50
# 30328/30328 [==============================] - 114s 4ms/step - loss: 0.0329 - accuracy: 0.9893 - val_loss: 0.0310 - val_accuracy: 0.9888
# Epoch 32/50
# 30328/30328 [==============================] - 114s 4ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 0.0351 - val_accuracy: 0.9884
# Epoch 33/50
# 30328/30328 [==============================] - 117s 4ms/step - loss: 0.0334 - accuracy: 0.9892 - val_loss: 0.0315 - val_accuracy: 0.9897
# Epoch 34/50
# 30328/30328 [==============================] - 118s 4ms/step - loss: 0.0327 - accuracy: 0.9893 - val_loss: 0.0315 - val_accuracy: 0.9888
# Epoch 35/50
# 30328/30328 [==============================] - 120s 4ms/step - loss: 0.0332 - accuracy: 0.9893 - val_loss: 0.0316 - val_accuracy: 0.9892
# Epoch 36/50
# 30328/30328 [==============================] - 120s 4ms/step - loss: 0.0336 - accuracy: 0.9893 - val_loss: 0.0313 - val_accuracy: 0.9902
# Epoch 37/50
# 30328/30328 [==============================] - 117s 4ms/step - loss: 0.0335 - accuracy: 0.9891 - val_loss: 0.0307 - val_accuracy: 0.9904
# Epoch 38/50
# 30328/30328 [==============================] - 117s 4ms/step - loss: 0.0335 - accuracy: 0.9893 - val_loss: 0.0294 - val_accuracy: 0.9902
# Epoch 39/50
# 30328/30328 [==============================] - 117s 4ms/step - loss: 0.0339 - accuracy: 0.9892 - val_loss: 0.0324 - val_accuracy: 0.9894
# Epoch 40/50
# 30328/30328 [==============================] - 115s 4ms/step - loss: 0.0334 - accuracy: 0.9892 - val_loss: 0.0334 - val_accuracy: 0.9892
# Epoch 41/50
# 30328/30328 [==============================] - 102s 3ms/step - loss: 0.0342 - accuracy: 0.9893 - val_loss: 0.0310 - val_accuracy: 0.9900
# Epoch 42/50
# 30328/30328 [==============================] - 102s 3ms/step - loss: 0.0339 - accuracy: 0.9891 - val_loss: 0.0305 - val_accuracy: 0.9903
# Epoch 43/50
# 30328/30328 [==============================] - 103s 3ms/step - loss: 0.0333 - accuracy: 0.9892 - val_loss: 0.0317 - val_accuracy: 0.9894
# Epoch 44/50
# 30328/30328 [==============================] - 101s 3ms/step - loss: 0.0342 - accuracy: 0.9891 - val_loss: 0.0342 - val_accuracy: 0.9899
# Epoch 45/50
# 30328/30328 [==============================] - 102s 3ms/step - loss: 0.0352 - accuracy: 0.9886 - val_loss: 0.0327 - val_accuracy: 0.9891
# Epoch 46/50
# 30328/30328 [==============================] - 106s 3ms/step - loss: 0.0351 - accuracy: 0.9891 - val_loss: 0.0301 - val_accuracy: 0.9901
# Epoch 47/50
# 30328/30328 [==============================] - 90s 3ms/step - loss: 0.0330 - accuracy: 0.9892 - val_loss: 0.0347 - val_accuracy: 0.9881
# Epoch 48/50
# 30328/30328 [==============================] - 64s 2ms/step - loss: 0.0339 - accuracy: 0.9892 - val_loss: 0.0348 - val_accuracy: 0.9881
# Epoch 49/50
# 30328/30328 [==============================] - 64s 2ms/step - loss: 0.0351 - accuracy: 0.9887 - val_loss: 0.0334 - val_accuracy: 0.9885
# Epoch 50/50
# 30328/30328 [==============================] - 65s 2ms/step - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.0344 - val_accuracy: 0.9892
# 452/452 [==============================] - 1s 2ms/step
#   Model  Benign Samples  Malicious Samples F1 score    FN    FP
# 0   DNN          445522              11353    81.2%  3546  1712

# %%
from sklearn.metrics import f1_score

# ---------- Decision Tree ----------
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
f1 = f1_score(y_test, y_pred_dt, zero_division=0)
cm = confusion_matrix(y_test, y_pred_dt)
tn, fp, fn, tp = cm.ravel()
print("DT is ready")
results.append(["DT", tn, tp, f"{f1*100:.1f}%", fn, fp])
# Out:
# DT is ready

# %%
# ---------- Random Forest ----------
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
# ---------- Random Forest ----------
y_pred_rf = rf.predict(X_test)

f1 = f1_score(y_test, y_pred_rf, zero_division=0)
cm = confusion_matrix(y_test, y_pred_rf)
tn, fp, fn, tp = cm.ravel()

results.append(["RF", tn, tp, f"{f1*100:.1f}%", fn, fp])
print("RF is ready")
# Out:
# RF is ready

# %%
# ---------- Extra Trees ----------
et = ExtraTreesClassifier(n_estimators=100)
et.fit(X_train, y_train)
# ---------- Extra Trees ----------
y_pred_et = et.predict(X_test)

f1 = f1_score(y_test, y_pred_et, zero_division=0)
cm = confusion_matrix(y_test, y_pred_et)
tn, fp, fn, tp = cm.ravel()

results.append(["ET", tn, tp, f"{f1*100:.1f}%", fn, fp])
print("ET is ready")
# Out:
# ET is ready

# %%
from sklearn.metrics import f1_score, confusion_matrix

# Clean column names for XGBoost compatibility
X.columns = [col.replace("[", "_").replace("]", "") for col in X.columns]
# Drop Timestamp, use remaining as features
X = df.drop(columns=['Timestamp', 'Flag'], errors='ignore')
y = df['Flag']

# Fix column names for XGBoost
X.columns = [col.replace("[", "_").replace("]", "") for col in X.columns]

# Stratified split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.7, random_state=42, stratify=y
)
# ---------- XGBoost ----------
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', base_score=0.5)
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)

f1 = f1_score(y_test, y_pred_xgb, zero_division=0)
cm = confusion_matrix(y_test, y_pred_xgb)
tn, fp, fn, tp = cm.ravel()

results.append(["XGBoost", tn, tp, f"{f1*100:.1f}%", fn, fp])
# Out:
# c:\Users\Lenovo\anaconda3\envs\ivn-ids\lib\site-packages\xgboost\training.py:183: UserWarning: [21:24:36] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
# Save to DataFrame
results_df = pd.DataFrame(results, columns=["Model", "Benign Samples", "Malicious Samples", "F1 score", "FN", "FP"])

# Save to CSV and LaTeX
results_df.to_csv("road_IDS_evaluation_results.csv", index=False)
display(results_df)
# Out:
#      Model  Benign Samples  Malicious Samples F1 score    FN    FP
# 0      DNN          445522              11353    81.2%  3546  1712
# 1       DT          446315              13205    91.0%  1694   919
# 2       RF          446323              13215    91.1%  1684   911
# 3       ET          446336              13196    91.0%  1703   898
# 4  XGBoost          446303              13217    91.0%  1682   931

# %%
import joblib
# Save the model
dnn.save("road/models/dnn_model.h5")
joblib.dump(rf, 'road/models/rf_model.pkl')
joblib.dump(xgb, 'road/models/xgb_model.pkl')
joblib.dump(dt, 'road/models/dt_model.pkl')
joblib.dump(et, 'road/models/et_model.pkl')
# Out:
# ['road/models/et_model.pkl']
